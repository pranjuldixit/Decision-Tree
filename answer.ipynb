# %% [markdown]
# """
# Decision Tree Assignment (Q1-Q15)
# Bank Marketing Dataset
#
# THEORETICAL ANSWERS
#
# Q1. Decision Tree:
# A Decision Tree is a supervised learning algorithm that splits data into branches.
# Structure:
# - Root Node: Starting point
# - Internal Nodes: Decision points
# - Leaf Nodes: Final outcomes
#
# Q2. Gini vs Entropy:
# Gini measures impurity and is faster.
# Entropy uses information gain and is computationally heavier.
# Scikit-learn uses Gini by default.
#
# Q3. Overfitting:
# Occurs when training accuracy is very high but testing accuracy is low.
#
# Q4. Pruning:
# Pre-pruning: Restrict tree growth during training.
# Post-pruning: Remove branches after training.
#
# Q5. Feature Importance:
# Shows which features contribute most to predictions.
# """

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv(r"G:\Pw skills\Assignment 46 ()\bank.csv")

# %%
# Q6 Data Understanding

print("FIRST 5 ROWS")
print(df.head())

print("\nSHAPE")
print(df.shape)

print("\nCOLUMN NAMES")
print(df.columns)

print("\nDATA TYPES")
print(df.dtypes)

print("\nINTERPRETATION")
print("Dataset contains numerical and categorical variables.")
# Out:
# FIRST 5 ROWS
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes
#
# SHAPE
# (11162, 17)
#
# COLUMN NAMES
# ...

# %%
# Q7 Data Cleaning
print("\nMISSING VALUES")
print(df.isnull().sum())

print("\nDUPLICATES")
print(df.duplicated().sum())

df.drop_duplicates(inplace=True)

# Missing Value Handling

for col in df.columns:

    # Numeric columns
    if pd.api.types.is_numeric_dtype(df[col]):
        df[col] = df[col].fillna(df[col].median())

    # All non-numeric columns
    else:
        df[col] = df[col].fillna(df[col].mode()[0])
# Out:
# MISSING VALUES
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64
#
# DUPLICATES
# 0

# %%
# Q8 Data Preprocessing
encoder = LabelEncoder()

for col in df.columns:
    if df[col].dtype == "object":
        df[col] = encoder.fit_transform(df[col])

print("\nINTERPRETATION")
print("Label Encoding used to convert categorical values into numbers.")

# Q9 Feature Selection & Splitting
target = df.columns[-1]

X = df.drop(target, axis=1)
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42
)

print("\nINTERPRETATION")
print("Train-test split prevents overfitting and evaluates model performance.")
# Out:
# INTERPRETATION
# Label Encoding used to convert categorical values into numbers.
#
# INTERPRETATION
# Train-test split prevents overfitting and evaluates model performance.

# %%
X = df.drop(target, axis=1)
y = df[target]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.columns:
    if df[col].dtype == 'object':
        df[col] = le.fit_transform(df[col].astype(str))

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
print(df.select_dtypes(include='object').columns)
# Out:
# Index([], dtype='str')

# %%
# Convert all categorical columns to numbers
df = pd.get_dummies(df, drop_first=True)

print(df.head())
# Out:
#    age  balance  day  duration  campaign  pdays  previous  job_blue-collar  \
# 0   59     2343    5      1042         1     -1         0            False
# 1   56       45    5      1467         1     -1         0            False
# 2   41     1270    5      1389         1     -1         0            False
# 3   55     2476    5       579         1     -1         0            False
# 4   54      184    5       673         2     -1         0            False
#
#    job_entrepreneur  job_housemaid  ...  month_jun  month_mar  month_may  \
# 0             False          False  ...      False      False       True
# 1             False          False  ...      False      False       True
# 2             False          False  ...      False      False       True
# 3             False          False  ...      False      False       True
# 4             False          False  ...      False      False       True
#
#    month_nov  month_oct  month_sep  poutcome_other  poutcome_success  \
# ...

# %%
# Q10 Model Building
model1 = DecisionTreeClassifier(
    criterion="gini",
    max_depth=5,
    random_state=42
)

model1.fit(X_train, y_train)

y_pred = model1.predict(X_test)

print("\nINTERPRETATION")
print("max_depth controls the depth of the tree.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 8
#       4     max_depth=5,
#       5     random_state=42
#       6 )
#       7
# ----> 8 model1.fit(X_train, y_train)
#       9
#      10 y_pred = model1.predict(X_test)
#      11
#
# File c:\Users\NCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\NCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\tree\_classes.py:1027, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
# ...

# %%
print(X_train.dtypes)
print(X_train.select_dtypes(include='object').columns)
# Out:
# age          int64
# job            str
# marital        str
# education      str
# default        str
# balance      int64
# housing        str
# loan           str
# contact        str
# day          int64
# month          str
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# poutcome       str
# dtype: object
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome'],
#       dtype='str')
# C:\Users\NCS\AppData\Local\Temp\ipykernel_13448\2237928011.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Load Dataset
df = pd.read_csv(r"G:\Pw skills\Assignment 46 ()\bank.csv", sep=';')

# Data Understanding
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns)
print("\nData Types:")
print(df.dtypes)

# Missing Values
print("\nMissing Values:")
print(df.isnull().sum())

# Remove duplicates
df.drop_duplicates(inplace=True)

# Fill Missing Values
for col in df.columns:
    if df[col].dtype in ['object', 'string']:
        df[col] = df[col].fillna(df[col].mode()[0])
    else:
        df[col] = df[col].fillna(df[col].median())

# Separate Target
y = df['y']
X = df.drop('y', axis=1)

# Convert all categorical features into numbers
X = pd.get_dummies(X, drop_first=True)

# Convert target into numeric
y = y.map({'yes': 1, 'no': 0})

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# Decision Tree Model
model1 = DecisionTreeClassifier(
    criterion='gini',
    max_depth=5,
    random_state=42
)

model1.fit(X_train, y_train)

# Predictions
y_pred = model1.predict(X_test)

# Accuracy
acc = accuracy_score(y_test, y_pred)

print("\nAccuracy Score:")
print(acc)

# Confusion Matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Overfitting Check
train_acc = model1.score(X_train, y_train)
test_acc = model1.score(X_test, y_test)

print("\nTraining Accuracy:", train_acc)
print("Testing Accuracy:", test_acc)

if train_acc - test_acc > 0.10:
    print("Model is Overfitting")
else:
    print("Model is Generalizing Well")

# Pruned Model
model2 = DecisionTreeClassifier(
    criterion='gini',
    max_depth=3,
    min_samples_split=20,
    random_state=42
)

model2.fit(X_train, y_train)

pred2 = model2.predict(X_test)

acc2 = accuracy_score(y_test, pred2)

print("\nPruned Model Accuracy:", acc2)

# Feature Importance
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model1.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print("\nTop 5 Important Features:")
print(importance.head())

# Plot Feature Importance
plt.figure(figsize=(10,5))
sns.barplot(
    data=importance.head(5),
    x='Importance',
    y='Feature'
)

plt.title("Top 5 Feature Importance")
plt.show()
# Out:
# Shape: (11162, 1)
#
# Columns:
# Index(['age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit'], dtype='str')
#
# Data Types:
# age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit    str
# dtype: object
#
# Missing Values:
# age,job,marital,education,default,balance,housing,loan,contact,day,month,duration,campaign,pdays,previous,poutcome,deposit    0
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\NCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# ...

# %%
# Convert categorical columns to numeric

categorical_cols = [
    'job', 'marital', 'education',
    'default', 'housing', 'loan',
    'contact', 'month', 'poutcome'
]

df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Target variable
y = df['y']

# Features
X = df.drop('y', axis=1)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print(X_train.select_dtypes(include=['object', 'string']).columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 9
#       5     'default', 'housing', 'loan',
#       6     'contact', 'month', 'poutcome'
#       7 ]
#       8
# ----> 9 df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
#      10
#      11 # Target variable
#      12 y = df['y']
#
# File c:\Users\NCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\encoding.py:171, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     169     raise TypeError("Input must be a list-like for parameter `columns`")
#     170 else:
# --> 171     data_to_encode = data[columns]
#     173 # validate prefixes and separator to avoid silently dropping cols
#     174 def check_len(item, name: str) -> None:
#
# ...

# %%
# Q11 Model Evaluation
acc = accuracy_score(y_test, y_pred)

print("\nACCURACY")
print(acc)

print("\nCONFUSION MATRIX")
print(confusion_matrix(y_test, y_pred))

print("\nCLASSIFICATION REPORT")
print(classification_report(y_test, y_pred))

print("\nINTERPRETATION")
print("Precision = Correct positive predictions / Total positive predictions")
print("Recall = Correct positive predictions / Actual positives")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Q11 Model Evaluation
# ----> 2 acc = accuracy_score(y_test, y_pred)
#       3
#       4 print("\nACCURACY")
#       5 print(acc)
#
# NameError: name 'y_pred' is not defined

# %%
# Q12 Overfitting Check
train_acc = model1.score(X_train, y_train)
test_acc = model1.score(X_test, y_test)

print("\nTRAIN ACCURACY:", train_acc)
print("TEST ACCURACY:", test_acc)

if train_acc - test_acc > 0.10:
    print("Model is Overfitting")
elif test_acc > train_acc:
    print("Model is Underfitting")
else:
    print("Model is Balanced")

# Q13 Pruning Experiment
model2 = DecisionTreeClassifier(
    criterion="gini",
    max_depth=3,
    min_samples_split=20,
    random_state=42
)

model2.fit(X_train, y_train)

pred2 = model2.predict(X_test)

acc2 = accuracy_score(y_test, pred2)

print("\nORIGINAL MODEL ACCURACY:", acc)
print("PRUNED MODEL ACCURACY:", acc2)

print("\nINTERPRETATION")
print("Model with better testing accuracy should be selected.")

# Q14 Feature Importance
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": model1.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

print("\nTOP 5 IMPORTANT FEATURES")
print(importance.head())

plt.figure(figsize=(8,5))
sns.barplot(
    data=importance.head(5),
    x="Importance",
    y="Feature"
)
plt.title("Top 5 Feature Importance")
plt.show()

print("\nINTERPRETATION")
print("Top-ranked features influence predictions the most.")

# Q15 Business Insights
print("\nBUSINESS INSIGHTS")
print("Customers matching high-importance feature patterns are more likely to say YES.")
print("The bank should target these customers with personalized marketing campaigns.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Q12 Overfitting Check
# ----> 2 train_acc = model1.score(X_train, y_train)
#       3 test_acc = model1.score(X_test, y_test)
#       4
#       5 print("\nTRAIN ACCURACY:", train_acc)
#
# File c:\Users\NCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:566, in ClassifierMixin.score(self, X, y, sample_weight)
#     541 """
#     542 Return :ref:`accuracy <accuracy_score>` on provided data and labels.
#     543
#    (...)    562     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     563 """
#     564 from sklearn.metrics import accuracy_score
# --> 566 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# ...
